# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv(r"C:\Users\Sahm9\Work\Digital_Futures\Python\Module4_Predictive_Modelling\swan project\Swan_Project\2. Saad\Project Data.csv")
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
df.tail()
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female             No
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male             No
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female             No
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female             No
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male             No
#
# ...

# %%
df.shape
# Out:
# (7043, 31)

# %%
df.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Reason          object
# dtype: object

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Reason         5174
# dtype: int64

# %%
df.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Churn Value
# count      7043.000000  7043.000000
# mean         64.761692     0.265370
# std          30.090047     0.441561
# min          18.250000     0.000000
# 25%          35.500000     0.000000
# 50%          70.350000     0.000000
# 75%          89.850000     1.000000
# max         118.750000     1.000000

# %%
df.corr(numeric_only=True)
# Out:
#                  Count  Zip Code  Latitude  Longitude  Tenure Months  \
# Count              NaN       NaN       NaN        NaN            NaN
# Zip Code           NaN  1.000000  0.895743  -0.784271       0.001041
# Latitude           NaN  0.895743  1.000000  -0.876779      -0.001631
# Longitude          NaN -0.784271 -0.876779   1.000000      -0.001678
# Tenure Months      NaN  0.001041 -0.001631  -0.001678       1.000000
# Monthly Charges    NaN -0.004596 -0.019899   0.024098       0.247900
# Churn Value        NaN  0.003346 -0.003384   0.004594      -0.352229
#
#                  Monthly Charges  Churn Value
# Count                        NaN          NaN
# Zip Code               -0.004596     0.003346
# Latitude               -0.019899    -0.003384
# Longitude               0.024098     0.004594
# Tenure Months           0.247900    -0.352229
# Monthly Charges         1.000000     0.193356
# Churn Value             0.193356     1.000000

# %%
sns.heatmap(df.corr(numeric_only = True), 
            annot = True, 
            vmin = -1, 
            vmax = + 1, 
            mask = np.triu(df.corr(numeric_only=True)),
            cmap = 'mako')
plt.show()

# %%
df['Churn Reason'].value_counts()
# Out:
# Churn Reason
# Attitude of support person                   192
# Competitor offered higher download speeds    189
# Competitor offered more data                 162
# Don't know                                   154
# Competitor made better offer                 140
# Attitude of service provider                 135
# Competitor had better devices                130
# Network reliability                          103
# Product dissatisfaction                      102
# Price too high                                98
# Service dissatisfaction                       89
# Lack of self-service on Website               88
# Extra data charges                            57
# Moved                                         53
# Limited range of services                     44
# Long distance charges                         44
# Lack of affordable download/upload speed      44
# Poor expertise of phone support               20
# Poor expertise of online support              19
# ...

# %%
df[df['Churn Value']==1][['Gender', 'Senior Citizen', 'Partner', 'Dependents']].groupby('Gender').value_counts()
# Out:
# Gender  Senior Citizen  Partner  Dependents
# Female  No              No       No            439
#                         Yes      No            209
#         Yes             No       No            155
#                         Yes      No             76
#         No              Yes      Yes            29
#                         No       Yes            22
#         Yes             Yes      Yes             5
#                         No       Yes             4
# Male    No              No       No            438
#                         Yes      No            213
#         Yes             No       No            118
#                         Yes      No            115
#         No              No       Yes            23
#                         Yes      Yes            20
#         Yes             Yes      Yes             2
#                         No       Yes             1
# Name: count, dtype: int64

# %%
df[df['Churn Value']==1][['Senior Citizen']].value_counts()
# Out:
# Senior Citizen
# No                1393
# Yes                476
# Name: count, dtype: int64

# %%
df[df['Churn Value']==1][['Gender']].value_counts()
# Out:
# Gender
# Female    939
# Male      930
# Name: count, dtype: int64

# %%
df[df['Churn Value']==1][['Dependents']].value_counts()
# Out:
# Dependents
# No            1763
# Yes            106
# Name: count, dtype: int64

# %%
df[df['Churn Value']==1][['Partner']].value_counts()
# Out:
# Partner
# No         1200
# Yes         669
# Name: count, dtype: int64

# %%
df[df['Churn Reason']=='Attitude of support person'].value_counts('Tech Support') # This is potentially an interesting find. Most people that dislike the support don't have tech support.
# Out:
# Tech Support
# No                     146
# Yes                     28
# No internet service     18
# Name: count, dtype: int64

# %%
df[df['Churn Value']==1].pivot_table(
    index = 'Gender', 
    columns = ['Senior Citizen','Partner', 'Dependents'], 
    aggfunc = {'Count':'count'}
)
# Out:
#                Count
# Senior Citizen    No               Yes
# Partner           No      Yes       No      Yes
# Dependents        No Yes   No Yes   No Yes   No Yes
# Gender
# Female           439  22  209  29  155   4   76   5
# Male             438  23  213  20  118   1  115   2

# %%
df_churn = df[df['Churn Value'] == 1]
df_churn.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %% [markdown]
# # Slide 1: Demographics

# %%
sns.countplot(df_churn, x='Churn Label', hue='Gender', stat='percent', palette='mako')
plt.title(label='Churners by Gender')
plt.xlabel(xlabel='Have They Churned?')
plt.ylabel(ylabel='Churn Percentage')
plt.legend(loc='upper right')
plt.show()

# %%
sns.countplot(df_churn, x='Churn Label', hue='Dependents', stat='percent', palette='mako')
plt.title(label='Churners with and without Dependents')
plt.xlabel(xlabel='Have They Churned?')
plt.ylabel(ylabel='Churn Percentage')
plt.legend(title='Dependents', loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       3 plt.xlabel(xlabel='Have They Churned?')
#       4 plt.ylabel(ylabel='Churn Percentage')
# ----> 5 plt.legend(legend='Dependents', loc='upper right')
#       6 plt.show()
#
# File c:\Users\Sahm9\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3588, in legend(*args, **kwargs)
#    3586 @_copy_docstring_and_deprecators(Axes.legend)
#    3587 def legend(*args, **kwargs) -> Legend:
# -> 3588     return gca().legend(*args, **kwargs)
#
# File c:\Users\Sahm9\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:342, in Axes.legend(self, *args, **kwargs)
#     225 """
#     226 Place a legend on the Axes.
#     227
#    (...)
#     339 .. plot:: gallery/text_labels_and_annotations/legend.py
#     340 """
#     341 handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
# ...

# %%
sns.countplot(df_churn, x='Churn Label', hue='Senior Citizen', stat='percent', palette='mako')
plt.title(label='Churners by Age')
plt.xlabel(xlabel='Have They Churned?')
plt.ylabel(ylabel='Churn Percentage')
plt.legend(title = 'Senior Citizen', loc='upper right')
plt.show()

# %%
sns.countplot(df_churn, x='Churn Label', hue='Partner', stat='percent', palette='mako')
plt.title(label='Churners with and without Partners')
plt.xlabel(xlabel='Have They Churned?')
plt.ylabel(ylabel='Churn Percentage')
plt.legend(title='Partners', loc='upper right')
plt.show()

# %% [markdown]
# # Slide 2: Why Churning?

# %%
sns.barplot(data=df['Churn Reason'].value_counts(), palette='mako')
plt.ylabel('Number of Churners')
plt.xticks(rotation = 90)
plt.show()

# %%
df_churn.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
df[df['Churn Value']==1].pivot_table(
    index = 'Gender', 'Senior Citizen'
    columns = ['Senior Citizen','Partner', 'Dependents'], 
    aggfunc = {'Count':'count'}
)
# Out:
#                Count
# Senior Citizen    No               Yes
# Partner           No      Yes       No      Yes
# Dependents        No Yes   No Yes   No Yes   No Yes
# Gender
# Female           439  22  209  29  155   4   76   5
# Male             438  23  213  20  118   1  115   2
